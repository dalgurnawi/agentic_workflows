# %%
# Import packages
import ast
import json
from enum import Enum
from pathlib import Path
import psycopg2
import ollama
import pandas as pd
from IPython.display import Image, Markdown, display
from tqdm import tqdm
import os
import urllib.parse
from sqlalchemy import create_engine

# %%
MODEL = "gpt-oss:20b"
TEMPERATURE = 0
DB_NAME=os.getenv('DB_NAME')
USERNAME=os.getenv('USERNAME')
PASSWORD=urllib.parse.quote(os.getenv('PASSWORD'))
HOSTNAME=os.getenv('HOSTNAME')
PORT=os.getenv('PORT')

# %%
# Creating conneciton to database
engine = create_engine(f'postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOSTNAME}/{DB_NAME}')

# %%
accounts_receivable = pd.read_sql("SELECT * FROM accounts_receivable", engine)
accounts_receivable
# Out:
#     invoice_number        date                               customer_name  \
# 0                1  2025-05-01                              Planet Express
# 1                2  2025-09-01                Mom's Friendly Robot Factory
# 2                3  2025-10-01                                 Romanticorp
# 3                4  2025-01-18   Hal Insitute for Criminally Insane Robots
# 4                5  2025-01-21    Cookieville Minimum-Security Orphanarium
# 5                6  2025-01-29                             Panucci's Pizza
# 6                7  2025-02-02                              Planet Express
# 7                8  2025-02-02                                 Romanticorp
# 8                9  2025-03-02  Malfunctioning Eddie's Rocket-Car Emporium
# 9               10  2025-05-02    Cookieville Minimum-Security Orphanarium
# 10              11  2025-07-02                Mom's Friendly Robot Factory
# 11              12  2025-10-02   Hal Insitute for Criminally Insane Robots
# 12              13  2025-02-15                             Panucci's Pizza
# 13              14  2025-02-18                 Democratic Order of Planets
#
#     customer_number    amount    due_date payment payment_date payment_id
# 0             12038   50000.0  2025-05-02    None         None       None
# 1             12000  100000.0  2025-09-02    None         None       None
# 2             12990   73640.0  2025-10-02    None         None       None
# 3             12010   12500.0  2025-02-18    None         None       None
# 4             11900   10000.0  2025-02-21    None         None       None
# 5             12933    1000.0  2025-02-28    None         None       None
# 6             12038   12300.0  2025-02-03    None         None       None
# 7             12990   50000.0  2025-02-03    None         None       None
# 8             12230   76000.0  2025-03-03    None         None       None
# 9             11900   80000.0  2025-05-02    None         None       None
# 10            12000  200000.0  2025-07-03    None         None       None
# 11            12010   12500.0  2025-10-03    None         None       None
# 12            12933    1000.0  2025-03-15    None         None       None
# 13            12001  120000.0  2025-03-18    None         None       None

# %%
payments= pd.read_sql("SELECT * FROM payments", engine)
payments
# Out:
#    transaction_id payment_date  payment_amount  \
# 0          948347   2025-01-31         25000.0
# 1           34847   2025-01-20        100000.0
# 2           29304   2025-01-02         12500.0
# 3         3837459   2025-10-02         10000.0
# 4          390576   2025-02-14         76000.0
# 5          302947   2025-02-18         25000.0
# 6           39506   2025-02-28          1000.0
# 7         2394759   2025-01-03         76000.0
# 8          390475   2025-03-13         80000.0
#
#                           payment_reference
# 0      12038 - 1 - We'll pay the rest later
# 1  Customer Nr 12000 - Invoice Nr 2 - Mom's
# 2                                 12010 - 4
# 3                               11900  - 5
# 4                    12990  - Invoice Nr. 3
# 5                12038 - 1 - Second payment
# 6                        12933 - 6 - Grazie
# 7      A little something for your troubles
# 8                                 11900 -10

# %%
class ResponseFormat(Enum):
    JSON = "json_object"
    TEXT = "text"


def call_model(
    prompt: str, response_format: ResponseFormat = ResponseFormat.TEXT
) -> str:
    response = ollama.generate(
        model=MODEL,
        prompt=prompt,
        keep_alive="1h",
        format="" if response_format == ResponseFormat.TEXT else "json",
        options={"temperature": TEMPERATURE},
    )
    return response["response"]

# %%
# %%time
task = f""" You have been given an accounts receivable invoice {accounts_receivable} and a received payment {payments}. Assess whether the payment relates to the invoice. 
            If there is no match, return an empty dictionary. If it does, UPDATE the invoice data with relevant payment information and return 
            the updated record as a dictionary with all invoice fields. Do not create any new columns for accounts receivables. Return the updated accounts receivables data as
            a dictionary with no other additional text."""
response = call_model(task)
# Out:
# CPU times: user 75.3 ms, sys: 489 ms, total: 564 ms
# Wall time: 45min 24s

# %%
print(response)
# Out:
# {"1":{"invoice_number":1,"date":"2025-05-01","customer_name":"Planet Express","customer_number":12038,"amount":50000.0,"due_date":"2025-05-02","payment":50000.0,"payment_date":"2025-02-18","payment_id":302947},"2":{"invoice_number":2,"date":"2025-09-01","customer_name":"Mom's Friendly Robot Factory","customer_number":12000,"amount":100000.0,"due_date":"2025-09-02","payment":100000.0,"payment_date":"2025-01-20","payment_id":34847},"3":{"invoice_number":3,"date":"2025-10-01","customer_name":"Romanticorp","customer_number":12990,"amount":73640.0,"due_date":"2025-10-02","payment":12500.0,"payment_date":"2025-01-02","payment_id":29304},"4":{"invoice_number":4,"date":"2025-01-18","customer_name":"Hal Insitute for Criminally Insane Robots","customer_number":12010,"amount":12500.0,"due_date":"2025-02-18","payment":10000.0,"payment_date":"2025-10-02","payment_id":3837459},"5":{"invoice_number":5,"date":"2025-01-21","customer_name":"Cookieville Minimum-Security Orphanarium","customer_number":11900,"amount":10000.0,"due_date":"2025-02-21","payment":76000.0,"payment_date":"2025-02-14","payment_id":390576},"6":{"invoice_number":6,"date":"2025-01-29","customer_name":"Panucci's Pizza","customer_number":12933,"amount":1000.0,"due_date":"2025-02-28","payment":1000.0,"payment_date":"2025-02-28","payment_id":39506},"7":{"invoice_number":7,"date":"2025-02-02","customer_name":"Planet Express","customer_number":12038,"amount":12300.0,"due_date":"2025-02-03","payment":null,"payment_date":null,"payment_id":null},"8":{"invoice_number":8,"date":"2025-02-02","customer_name":"Romanticorp","customer_number":12990,"amount":50000.0,"due_date":"2025-02-03","payment":null,"payment_date":null,"payment_id":null},"9":{"invoice_number":9,"date":"2025-03-02","customer_name":"Malfunctioning Eddie's Rocket-Car Emporium","customer_number":12230,"amount":76000.0,"due_date":"2025-03-03","payment":null,"payment_date":null,"payment_id":null},"10":{"invoice_number":10,"date":"2025-05-02","customer_name":"Cookieville Minimum-Security Orphanarium","customer_number":11900,"amount":80000.0,"due_date":"2025-05-02","payment":80000.0,"payment_date":"2025-03-13","payment_id":390475},"11":{"invoice_number":11,"date":"2025-07-02","customer_name":"Mom's Friendly Robot Factory","customer_number":12000,"amount":200000.0,"due_date":"2025-07-03","payment":null,"payment_date":null,"payment_id":null},"12":{"invoice_number":12,"date":"2025-10-02","customer_name":"Hal Insitute for Criminally Insane Robots","customer_number":12010,"amount":12500.0,"due_date":"2025-10-03","payment":null,"payment_date":null,"payment_id":null},"13":{"invoice_number":13,"date":"2025-02-15","customer_name":"Panucci's Pizza","customer_number":12933,"amount":1000.0,"due_date":"2025-03-15","payment":null,"payment_date":null,"payment_id":null},"14":{"invoice_number":14,"date":"2025-02-18","customer_name":"Democratic Order of Planets","customer_number":12001,"amount":120000.0,"due_date":"2025-03-18","payment":null,"payment_date":null,"payment_id":null}}

# %%
data = json.loads(response)

# %%
data
# Out:
# {'1': {'invoice_number': 1,
#   'date': '2025-05-01',
#   'customer_name': 'Planet Express',
#   'customer_number': 12038,
#   'amount': 50000.0,
#   'due_date': '2025-05-02',
#   'payment': 50000.0,
#   'payment_date': '2025-02-18',
#   'payment_id': 302947},
#  '2': {'invoice_number': 2,
#   'date': '2025-09-01',
#   'customer_name': "Mom's Friendly Robot Factory",
#   'customer_number': 12000,
#   'amount': 100000.0,
#   'due_date': '2025-09-02',
#   'payment': 100000.0,
#   'payment_date': '2025-01-20',
#   'payment_id': 34847},
#  '3': {'invoice_number': 3,
#   'date': '2025-10-01',
#   'customer_name': 'Romanticorp',
#   'customer_number': 12990,
#   'amount': 73640.0,
#   'due_date': '2025-10-02',
#   'payment': 12500.0,
#   'payment_date': '2025-01-02',
#   'payment_id': 29304},
#  '4': {'invoice_number': 4,
#   'date': '2025-01-18',
#   'customer_name': 'Hal Insitute for Criminally Insane Robots',
#   'customer_number': 12010,
#   'amount': 12500.0,
#   'due_date': '2025-02-18',
#   'payment': 10000.0,
#   'payment_date': '2025-10-02',
#   'payment_id': 3837459},
#  '5': {'invoice_number': 5,
#   'date': '2025-01-21',
#   'customer_name': 'Cookieville Minimum-Security Orphanarium',
#   'customer_number': 11900,
#   'amount': 10000.0,
#   'due_date': '2025-02-21',
#   'payment': 76000.0,
#   'payment_date': '2025-02-14',
#   'payment_id': 390576},
#  '6': {'invoice_number': 6,
#   'date': '2025-01-29',
#   'customer_name': "Panucci's Pizza",
#   'customer_number': 12933,
#   'amount': 1000.0,
#   'due_date': '2025-02-28',
#   'payment': 1000.0,
#   'payment_date': '2025-02-28',
#   'payment_id': 39506},
#  '7': {'invoice_number': 7,
#   'date': '2025-02-02',
#   'customer_name': 'Planet Express',
#   'customer_number': 12038,
#   'amount': 12300.0,
#   'due_date': '2025-02-03',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None},
#  '8': {'invoice_number': 8,
#   'date': '2025-02-02',
#   'customer_name': 'Romanticorp',
#   'customer_number': 12990,
#   'amount': 50000.0,
#   'due_date': '2025-02-03',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None},
#  '9': {'invoice_number': 9,
#   'date': '2025-03-02',
#   'customer_name': "Malfunctioning Eddie's Rocket-Car Emporium",
#   'customer_number': 12230,
#   'amount': 76000.0,
#   'due_date': '2025-03-03',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None},
#  '10': {'invoice_number': 10,
#   'date': '2025-05-02',
#   'customer_name': 'Cookieville Minimum-Security Orphanarium',
#   'customer_number': 11900,
#   'amount': 80000.0,
#   'due_date': '2025-05-02',
#   'payment': 80000.0,
#   'payment_date': '2025-03-13',
#   'payment_id': 390475},
#  '11': {'invoice_number': 11,
#   'date': '2025-07-02',
#   'customer_name': "Mom's Friendly Robot Factory",
#   'customer_number': 12000,
#   'amount': 200000.0,
#   'due_date': '2025-07-03',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None},
#  '12': {'invoice_number': 12,
#   'date': '2025-10-02',
#   'customer_name': 'Hal Insitute for Criminally Insane Robots',
#   'customer_number': 12010,
#   'amount': 12500.0,
#   'due_date': '2025-10-03',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None},
#  '13': {'invoice_number': 13,
#   'date': '2025-02-15',
#   'customer_name': "Panucci's Pizza",
#   'customer_number': 12933,
#   'amount': 1000.0,
#   'due_date': '2025-03-15',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None},
#  '14': {'invoice_number': 14,
#   'date': '2025-02-18',
#   'customer_name': 'Democratic Order of Planets',
#   'customer_number': 12001,
#   'amount': 120000.0,
#   'due_date': '2025-03-18',
#   'payment': None,
#   'payment_date': None,
#   'payment_id': None}}

# %%
df = pd.DataFrame()
for i in range(1,len(data)+1):
    ph_df = pd.json_normalize(data[f"{i}"])
    df = pd.concat([df, ph_df])
df
# Out:
# /var/folders/4s/q4zndhns13bdmf7q1_8p3crc0000gn/T/ipykernel_68564/472876252.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, ph_df])
#    invoice_number        date                               customer_name  \
# 0               1  2025-05-01                              Planet Express
# 0               2  2025-09-01                Mom's Friendly Robot Factory
# 0               3  2025-10-01                                 Romanticorp
# 0               4  2025-01-18   Hal Insitute for Criminally Insane Robots
# 0               5  2025-01-21    Cookieville Minimum-Security Orphanarium
# 0               6  2025-01-29                             Panucci's Pizza
# 0               7  2025-02-02                              Planet Express
# 0               8  2025-02-02                                 Romanticorp
# 0               9  2025-03-02  Malfunctioning Eddie's Rocket-Car Emporium
# 0              10  2025-05-02    Cookieville Minimum-Security Orphanarium
# 0              11  2025-07-02                Mom's Friendly Robot Factory
# 0              12  2025-10-02   Hal Insitute for Criminally Insane Robots
# 0              13  2025-02-15                             Panucci's Pizza
# 0              14  2025-02-18                 Democratic Order of Planets
#
#    customer_number    amount    due_date   payment payment_date payment_id
# 0            12038   50000.0  2025-05-02   50000.0   2025-02-18     302947
# 0            12000  100000.0  2025-09-02  100000.0   2025-01-20      34847
# 0            12990   73640.0  2025-10-02   12500.0   2025-01-02      29304
# 0            12010   12500.0  2025-02-18   10000.0   2025-10-02    3837459
# 0            11900   10000.0  2025-02-21   76000.0   2025-02-14     390576
# 0            12933    1000.0  2025-02-28    1000.0   2025-02-28      39506
# 0            12038   12300.0  2025-02-03       NaN         None       None
# 0            12990   50000.0  2025-02-03       NaN         None       None
# 0            12230   76000.0  2025-03-03       NaN         None       None
# 0            11900   80000.0  2025-05-02   80000.0   2025-03-13     390475
# 0            12000  200000.0  2025-07-03       NaN         None       None
# 0            12010   12500.0  2025-10-03       NaN         None       None
# 0            12933    1000.0  2025-03-15       NaN         None       None
# 0            12001  120000.0  2025-03-18       NaN         None       None
