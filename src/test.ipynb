# %%
from langchain_community.tools import WikipediaQueryRun, DuckDuckGoSearchRun
from langchain_community.utilities import WikipediaAPIWrapper
from langchain.tools import tool
from datetime import datetime
import pandas as pd
import os
import psycopg2
from dotenv import load_dotenv, find_dotenv
import urllib.parse

# %%
load_dotenv(find_dotenv())
DB_NAME=os.getenv('DB_NAME')
USERNAME=os.getenv('USERNAME')
PASSWORD=urllib.parse.quote(os.getenv('PASSWORD'))
HOSTNAME=os.getenv('HOSTNAME')
PORT=os.getenv('PORT')
# Creating conneciton to database
conn = psycopg2.connect(f"dbname={DB_NAME} user={USERNAME} password={PASSWORD}")

# %%
#@tool
def access_accounts_receivable():
    """ Function to access data tables in Postgres"""
    df =  pd.read_sql(f"SELECT * FROM accounts_receivable", conn)
    return df

# %%
access_accounts_receivable()
# Out:
# /var/folders/4s/q4zndhns13bdmf7q1_8p3crc0000gn/T/ipykernel_25737/111012956.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df =  pd.read_sql(f"SELECT * FROM accounts_receivable", conn)
#     invoice_number        date                               customer_name  \
# 0                1  2025-05-01                              Planet Express
# 1                2  2025-09-01                Mom's Friendly Robot Factory
# 2                3  2025-10-01                                 Romanticorp
# 3                4  2025-01-18   Hal Insitute for Criminally Insane Robots
# 4                5  2025-01-21    Cookieville Minimum-Security Orphanarium
# 5                6  2025-01-29                             Panucci's Pizza
# 6                7  2025-02-02                              Planet Express
# ...

# %%
keep_alive': '-1'}
